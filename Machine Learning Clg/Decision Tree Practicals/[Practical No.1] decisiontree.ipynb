# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in c:\users\gauri mohite\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\gauri mohite\anaconda3\lib\site-packages (from pydotplus) (3.0.4)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn import tree
import pydotplus
import matplotlib.image as pltimg

# %%
df = pd.read_csv(r"C:\Users\Gauri Mohite\Documents\Excel files(program)\DecisionTree.csv")

# %%
d={'Grey':0,'Yellow':1,'Brown':2,'Golden':3,'black-white':4,'black':5,'white':6,'green':7}
e={'herbivores':0,'carnivores':1,'omnivores':2}
f={'elephant':0,'giraffe':1,'monkey':2,'tiger':3,'Lion':4,
   'Zebra':5,'Buffalo':6,'cow':7,'crocodile':8,'Bear':9}
df['color']=df['color'].map(d)
df['type']=df['type'].map(e)
df['class']=df['class'].map(f)

# %%
features=['color','height','type']
X=df[features]
y=df['class']
print(X)
print(y)
# Out:
#     color  height  type
# 0       0      10     0
# 1       1      10     0
# 2       2       3     0
# 3       0      10     0
# 4       1       4     1
# 5       3       5     1
# 6       4       4     0
# 7       5       6     0
# 8       6       5     0
# 9       7       7     1
# 10      5       5     2
# 11      0      10     0
# 12      1      10     0
# 13      2       3     0
# 14      0      10     0
# 15      1       4     1
# 16      3       5     1
# 17      4       4     0
# 18      5       6     0
# 19      6       5     0
# 20      7       7     1
# 21      5       5     2
# 0     0
# 1     1
# 2     2
# 3     0
# 4     3
# 5     4
# 6     5
# 7     6
# 8     7
# 9     8
# 10    9
# 11    0
# 12    1
# 13    2
# 14    0
# 15    3
# 16    4
# 17    5
# 18    6
# 19    7
# 20    8
# 21    9
# Name: class, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
#import the model
#make an instance of model
clf=DecisionTreeClassifier(max_depth=2,random_state=10)
#train the model on the data
clf.fit(X_train,y_train)
#predict labels of unseen (test) data
clf.predict(X_test)
# Out:
# array([6, 6, 0, 3, 3, 6], dtype=int64)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.4, 0.8333333333333334, 'X[0] <= 0.5\ngini = 0.875\nsamples = 16\nvalue = [3, 1, 1, 2, 2, 2, 2, 2, 1]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6, 0.5, 'X[0] <= 4.5\ngini = 0.864\nsamples = 13\nvalue = [0, 1, 1, 2, 2, 2, 2, 2, 1]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.781\nsamples = 8\nvalue = [0, 1, 1, 2, 2, 2, 0, 0, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.64\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 0, 2, 2, 1]')]

# %%
fn=['color','height','type']
cn=['elephant','giraffe','monkey','tiger','Lion','Zebra','Buffalo','cow','crocodile','Bear']
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(4,4),dpi=300)
tree.plot_tree(clf,
               feature_names=fn,
               class_names=cn,
               filled=True)
fig.savefig('imagename.png')

# %%
import graphviz
fn=['colour', 'height', 'type']
data=tree.export_graphviz(clf, out_file=None, feature_names=fn)

graph = pydotplus.graph_from_dot_data(data)

#Image(graph.create_png())
graph.write_png('mydecisiontree.png')

img=pltimg.imread('mydecisiontree.png')

imgplot=plt.imshow(img)
plt.show()
