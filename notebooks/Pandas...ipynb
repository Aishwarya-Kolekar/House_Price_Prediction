# %%
import pandas as pd

# %%
f = pd.read_csv('C:\\Users\\HP\\python\\DecisionTree\\animal.csv')

# %%
f
# Out:
#           color  height        type      class
# 0          Grey    10.0  herbivores   elephant
# 1        Yellow     NaN  herbivores    giraffe
# 2         Brown     3.0  herbivores     monkey
# 3          Grey    10.0  herbivores   elephant
# 4           NaN     4.0  carnivores      tiger
# 5        Golden     5.0  carnivores       lion
# 6   Black-white     4.0  herbivores  not given
# 7         Black     6.0  herbivores    buffalo
# 8         White     NaN  herbivores        cow
# 9         Green     7.0  carnivores  crocodile
# 10        Black     5.0   omnivores       bear
# 11         Grey    10.0         NaN   elephant
# 12       Yellow    10.0  herbivores    giraffe
# 13        Brown     NaN  herbivores        NaN
# 14         Grey    10.0  herbivores   elephant
# 15       Yellow     4.0  carnivores      tiger
# 16       Golden     5.0  carnivores       lion
# 17  Black-white     4.0  herbivores      zebra
# 18        Black     6.0         NaN    buffalo
# ...

# %%
# to convert perticular string into the NaN value

f = pd.read_csv('C:\\Users\\HP\\python\\DecisionTree\\animal.csv', na_values = 'not given')
f
# Out:
#           color  height        type      class
# 0          Grey    10.0  herbivores   elephant
# 1        Yellow     NaN  herbivores    giraffe
# 2         Brown     3.0  herbivores     monkey
# 3          Grey    10.0  herbivores   elephant
# 4           NaN     4.0  carnivores      tiger
# 5        Golden     5.0  carnivores       lion
# 6   Black-white     4.0  herbivores        NaN
# 7         Black     6.0  herbivores    buffalo
# 8         White     NaN  herbivores        cow
# 9         Green     7.0  carnivores  crocodile
# 10        Black     5.0   omnivores       bear
# 11         Grey    10.0         NaN   elephant
# 12       Yellow    10.0  herbivores    giraffe
# 13        Brown     NaN  herbivores        NaN
# 14         Grey    10.0  herbivores   elephant
# 15       Yellow     4.0  carnivores      tiger
# 16       Golden     5.0  carnivores       lion
# 17  Black-white     4.0  herbivores      zebra
# 18        Black     6.0         NaN    buffalo
# ...

# %%
#to convert multiple perticular string from perticular coulmns into the NaN value

f = pd.read_csv('C:\\Users\\HP\\python\\DecisionTree\\animal.csv', na_values ={'type' :'no value'})
f
# Out:
#           color  height        type      class
# 0          Grey    10.0  herbivores   elephant
# 1        Yellow     NaN  herbivores    giraffe
# 2         Brown     3.0  herbivores     monkey
# 3          Grey    10.0  herbivores   elephant
# 4           NaN     4.0  carnivores      tiger
# 5        Golden     5.0  carnivores       lion
# 6   Black-white     4.0  herbivores  not given
# 7         Black     6.0  herbivores    buffalo
# 8         White     NaN  herbivores        cow
# 9         Green     7.0  carnivores  crocodile
# 10        Black     5.0   omnivores       bear
# 11         Grey    10.0         NaN   elephant
# 12       Yellow    10.0  herbivores    giraffe
# 13        Brown     NaN  herbivores        NaN
# 14         Grey    10.0  herbivores   elephant
# 15       Yellow     4.0  carnivores      tiger
# 16       Golden     5.0  carnivores       lion
# 17  Black-white     4.0  herbivores      zebra
# 18        Black     6.0         NaN    buffalo
# ...

# %%
#not to convert the default null factors to NaN value

f = pd.read_csv('C:\\Users\\HP\\python\\DecisionTree\\animal.csv',keep_default_na=False)
f
# Out:
#           color height        type      class
# 0          Grey     10  herbivores   elephant
# 1        Yellow         herbivores    giraffe
# 2         Brown      3  herbivores     monkey
# 3          Grey     10  herbivores   elephant
# 4                    4  carnivores      tiger
# 5        Golden      5  carnivores       lion
# 6   Black-white      4  herbivores  not given
# 7         Black      6  herbivores    buffalo
# 8         White         herbivores        cow
# 9         Green      7  carnivores  crocodile
# 10        Black      5   omnivores       bear
# 11         Grey     10    no value   elephant
# 12       Yellow     10  herbivores    giraffe
# 13        Brown   Null  herbivores
# 14         Grey     10  herbivores   elephant
# 15       Yellow      4  carnivores      tiger
# 16       Golden      5  carnivores       lion
# 17  Black-white      4  herbivores      zebra
# 18        Black      6                buffalo
# 19        White      5  herbivores        cow
# ...

# %%
f = pd.read_csv('C:\\Users\\HP\\python\\DecisionTree\\animal.csv')
f
# Out:
#           color  height        type      class
# 0          Grey      10  herbivores   elephant
# 1        Yellow       4  herbivores    giraffe
# 2         Brown       3  herbivores     monkey
# 3          Grey      10  herbivores   elephant
# 4        Yellow       4  carnivores      tiger
# 5        Golden       5  carnivores       lion
# 6   Black-white       4  herbivores      zebra
# 7         Black       6  herbivores    buffalo
# 8         White       5  herbivores        cow
# 9         Green       7  carnivores  crocodile
# 10        Black       5   omnivores       bear
# 11         Grey      10    no value   elephant
# 12       Yellow      10  herbivores    giraffe
# 13        Brown       3  herbivores     monkey
# 14         Grey      10  herbivores   elephant
# 15       Yellow       4  carnivores      tiger
# 16       Golden       5  carnivores       lion
# 17  Black-white       4  herbivores      zebra
# 18        Black       6  herbivores    buffalo
# ...

# %%
f.isnull().sum()
# Out:
# color     0
# height    0
# type      0
# class     0
# dtype: int64

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/b8/bb/7d1a8523711c7022601d17a8449b822dc5ffaf272692d3538771b0538631/pandas_profiling-3.1.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/93/3e/cb354fb2097fcf2fd5b5a342b10ae2a6e9363ba435b64e3e00c414064bc7/tangled_up_in_unicode-0.1.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/55/85/70c6602b078bd9e6f3da4f467047e906525c355a4dacd4f71b97a35d9897/joblib-1.0.1-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/d4/4e/00724eebf52854e65dabe2c190b4842afbda0e09817f415683a3130a123c/pydantic-1.9.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/8c/37/6c48a185038b29642e9789692f9882cea32dc834a05afcdaa0151ef0d13b/matplotlib-3.5.1-cp37-cp37m-win32.whl
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-98f09099f855> in <module>()
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
df = pd.read_csv('C:\\Users\\HP\\python\\DecisionTree\\diabetes.csv')
df

# %%
#To generate a report
profile = ProfileReport(df)
